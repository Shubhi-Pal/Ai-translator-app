# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhi-Pal/Ai-translator-app/blob/main/transcribesece.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome in google colab")
# Out:
# Welcome in google colab
